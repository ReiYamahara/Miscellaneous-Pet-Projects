# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from julia_and_mandelbrot_functions import *
from matplotlib.widgets import Slider

# %%
iteration_array = julia_set_frames(c = 0, x_pixels = 2000, iterations = 50)
julia_set_save_gif(iteration_array, dpi = 500, cmap = 'RdBu')

# %%
iteration_array = julia_set_frames(x_pixels = 1000, iterations = 150)
julia_set_slider_frames(iteration_array, dpi = 400)
# Out:
# /Users/reiyamahara/GitHub/Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/src/julia_and_mandelbrot_functions.py:40: RuntimeWarning: overflow encountered in absolute
#   condition = (abs(complex_array) >= 2) & (iteration_array[i - 1] > i) # absolute value of z is greater than 0 and the array value has not been filled
# /Users/reiyamahara/GitHub/Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/src/julia_and_mandelbrot_functions.py:39: RuntimeWarning: overflow encountered in square
#   complex_array = complex_array ** 2 + c
# /Users/reiyamahara/GitHub/Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/src/julia_and_mandelbrot_functions.py:39: RuntimeWarning: invalid value encountered in square
#   complex_array = complex_array ** 2 + c

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from julia_and_mandelbrot_functions import *

# %%
iteration_array = julia_set_frames(c = 0, x_pixels = 200, iterations = 50)
julia_set_save_gif(iteration_array, dpi = 50, cmap = 'RdBu')
# Out:
# /Users/reiyamahara/GitHub/Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/src/julia_and_mandelbrot_functions.py:38: RuntimeWarning: overflow encountered in absolute
#   condition = (abs(complex_array) >= 2) & (iteration_array[i - 1] > i) # absolute value of z is greater than 0 and the array value has not been filled
# /Users/reiyamahara/GitHub/Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/src/julia_and_mandelbrot_functions.py:37: RuntimeWarning: overflow encountered in square
#   complex_array = complex_array ** 2 + c
# /Users/reiyamahara/GitHub/Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/src/julia_and_mandelbrot_functions.py:37: RuntimeWarning: invalid value encountered in square
#   complex_array = complex_array ** 2 + c
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/rr/grm87jvx0gg_w0l6v0_pb8xc0000gn/T/ipykernel_37243/3466162262.py in <module>
#       1 iteration_array = julia_set_frames(c = 0, x_pixels = 2000, iterations = 50)
# ----> 2 julia_set_save_gif(iteration_array, dpi = 500, cmap = 'RdBu')
#
# ~/GitHub/Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/src/julia_and_mandelbrot_functions.py in julia_set_save_gif(iteration_array, interval, dpi, cmap, repeat_delay)
#     113     anim = animation.ArtistAnimation(fig, ims, interval = interval, blit = True, repeat_delay = repeat_delay)
#     114     file = f'../Miscellaneous-Pet-Projects/Mandelbrot and Julia Sets/gifs/julia_set_{cmap.lower()}_{len(iteration_array)}.gif'
# --> 115     anim.save(file, writer = 'pillow')
#
# ~/.venvs/adrinet_venv/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1093                         progress_callback(frame_number, total_frames)
#    1094                         frame_number += 1
# -> 1095                 writer.grab_frame(**savefig_kwargs)
#    1096
#    1097     def _step(self, *args):
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/.venvs/adrinet_venv/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     236             yield self
#     237         finally:
# --> 238             self.finish()
#     239
#     240
#
# ~/.venvs/adrinet_venv/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     512
#     513     def finish(self):
# --> 514         self._frames[0].save(
#     515             self.outfile, save_all=True, append_images=self._frames[1:],
#     516             duration=int(1000 / self.fps), loop=0)
#
# ~/.venvs/adrinet_venv/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Miscellaneous-Pet-Projects/Mandelbrot & Julia Sets/gifs/julia_set_rdbu_50.gif'

# %%
iteration_array = julia_set_frames(x_pixels = 2000, iterations = 50)
julia_set_save_gif(iteration_array, dpi = 500)
